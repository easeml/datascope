# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# from sklearn import set_config
# set_config(display='diagram')

from dspipes import Pipelines
from Experiment import Experiment

import numpy as np
# CAUTION: forksets has to be an np array

# %%
# datasets = 20NewsGroups, UCI, FashionMNIST

settings = {
    'iterations': 1, # number of MC iterations
    'run_label': True, # what experiment
    'run_poisoning': True,
    'ray': True, # use ray?
    'truncated': True, # TMC or MC?
    'run_forks': 0 # use forks? how many?
}

for i in range(0,4):
    name = f'pipe_{i}'
    model = Pipelines.create_numerical_pipeline(name, imputer=False)
    exp_name = f'label_i_1100_UCI_{name}'
    exp = Experiment(exp_name, model, dataset_name="UCI", save_path="./")
    exp.run(**settings)
# Out:
# Initiate experiment label_i_1100_UCI_pipe_0-i-1-time-24-11-2021-13-36-25
# [DataScope] => Running label noise experiment
# Successfully created the directory .//results/label_i_1100_UCI_pipe_0/i-1-time-24-11-2021-13-36-25/label/
# False
# condknn time:  0.018392933998256922
# [DataScope] => Start KNN recompute v1
# Recompute v1 0/100
# Recompute v1 1/100
# Recompute v1 2/100
# Recompute v1 3/100
# Recompute v1 4/100
# Recompute v1 5/100
# Recompute v1 6/100
# Recompute v1 7/100
# Recompute v1 8/100
# Recompute v1 9/100
# Recompute v1 10/100
# Recompute v1 11/100
# Recompute v1 12/100
# Recompute v1 13/100
# Recompute v1 14/100
# Recompute v1 15/100
# Recompute v1 16/100
# Recompute v1 17/100
# Recompute v1 18/100
# Recompute v1 19/100
# Recompute v1 20/100
# Recompute v1 21/100
# Recompute v1 22/100
# Recompute v1 23/100
# Recompute v1 24/100
# Recompute v1 25/100
# Recompute v1 26/100
# Recompute v1 27/100
# Recompute v1 28/100
# Recompute v1 29/100
# Recompute v1 30/100
# Recompute v1 31/100
# Recompute v1 32/100
# Recompute v1 33/100
# Recompute v1 34/100
# Recompute v1 35/100
# Recompute v1 36/100
# Recompute v1 37/100
# Recompute v1 38/100
# Recompute v1 39/100
# Recompute v1 40/100
# Recompute v1 41/100
# Recompute v1 42/100
# Recompute v1 43/100
# Recompute v1 44/100
# Recompute v1 45/100
# Recompute v1 46/100
# Recompute v1 47/100
# Recompute v1 48/100
# Recompute v1 49/100
# Recompute v1 50/100
# Recompute v1 51/100
# Recompute v1 52/100
# Recompute v1 53/100
# Recompute v1 54/100
# Recompute v1 55/100
# Recompute v1 56/100
# Recompute v1 57/100
# Recompute v1 58/100
# Recompute v1 59/100
# Recompute v1 60/100
# Recompute v1 61/100
# Recompute v1 62/100
# Recompute v1 63/100
# Recompute v1 64/100
# Recompute v1 65/100
# Recompute v1 66/100
# Recompute v1 67/100
# Recompute v1 68/100
# Recompute v1 69/100
# Recompute v1 70/100
# Recompute v1 71/100
# Recompute v1 72/100
# Recompute v1 73/100
# Recompute v1 74/100
# Recompute v1 75/100
# Recompute v1 76/100
# Recompute v1 77/100
# Recompute v1 78/100
# Recompute v1 79/100
# Recompute v1 80/100
# Recompute v1 81/100
# Recompute v1 82/100
# Recompute v1 83/100
# Recompute v1 84/100
# Recompute v1 85/100
# Recompute v1 86/100
# Recompute v1 87/100
# Recompute v1 88/100
# Recompute v1 89/100
# Recompute v1 90/100
# Recompute v1 91/100
# Recompute v1 92/100
# Recompute v1 93/100
# Recompute v1 94/100
# Recompute v1 95/100
# Recompute v1 96/100
# Recompute v1 97/100
# Recompute v1 98/100
# Recompute v1 99/100
# [ 8. 51. 52. 42. 53. 54. 55. 56. 13. 29. 57. 10. 58.  3. 59. 60. 33. 61.
#  49. 62. 63. 64. 65. 66.  6. 27. 67. 21. 16. 68. 19. 69. 22. 44. 32. 70.
#  71. 72. 73. 39. 15. 74. 23. 75. 14. 76. 77. 78. 79. 80. 81. 82. 12. 28.
#  35. 83. 47. 84.  4. 20. 18. 85. 40. 17. 86. 87. 24. 88. 25. 38. 89. 90.
#   1. 91. 92. 34. 26. 50. 93. 94. 30. 95. 96. 97.  0. 48. 36.  2. 98. 99.
#   9. 31. 41. 45. 43. 11. 46.  7.  5. 37.]
# recompute v1 condknn time:  1.0577805720022297
# [DataScope] => Start KNN recompute v2
# Recompute v2 0/100
# Recompute v2 1/100
# Recompute v2 2/100
# Recompute v2 3/100
# Recompute v2 4/100
# Recompute v2 5/100
# Recompute v2 6/100
# Recompute v2 7/100
# Recompute v2 8/100
# Recompute v2 9/100
# Recompute v2 10/100
# Recompute v2 11/100
# Recompute v2 12/100
# Recompute v2 13/100
# Recompute v2 14/100
# Recompute v2 15/100
# Recompute v2 16/100
# Recompute v2 17/100
# Recompute v2 18/100
# Recompute v2 19/100
# Recompute v2 20/100
# Recompute v2 21/100
# Recompute v2 22/100
# Recompute v2 23/100
# Recompute v2 24/100
# Recompute v2 25/100
# Recompute v2 26/100
# Recompute v2 27/100
# Recompute v2 28/100
# Recompute v2 29/100
# Recompute v2 30/100
# Recompute v2 31/100
# Recompute v2 32/100
# Recompute v2 33/100
# Recompute v2 34/100
# Recompute v2 35/100
# Recompute v2 36/100
# Recompute v2 37/100
# Recompute v2 38/100
# Recompute v2 39/100
# Recompute v2 40/100
# Recompute v2 41/100
# Recompute v2 42/100
# Recompute v2 43/100
# Recompute v2 44/100
# Recompute v2 45/100
# Recompute v2 46/100
# Recompute v2 47/100
# Recompute v2 48/100
# Recompute v2 49/100
# Recompute v2 50/100
# Recompute v2 51/100
# Recompute v2 52/100
# Recompute v2 53/100
# Recompute v2 54/100
# Recompute v2 55/100
# Recompute v2 56/100
# Recompute v2 57/100
# Recompute v2 58/100
# Recompute v2 59/100
# Recompute v2 60/100
# Recompute v2 61/100
# Recompute v2 62/100
# Recompute v2 63/100
# Recompute v2 64/100
# Recompute v2 65/100
# Recompute v2 66/100
# Recompute v2 67/100
# Recompute v2 68/100
# Recompute v2 69/100
# Recompute v2 70/100
# Recompute v2 71/100
# Recompute v2 72/100
# Recompute v2 73/100
# Recompute v2 74/100
# Recompute v2 75/100
# Recompute v2 76/100
# Recompute v2 77/100
# Recompute v2 78/100
# Recompute v2 79/100
# Recompute v2 80/100
# Recompute v2 81/100
# Recompute v2 82/100
# Recompute v2 83/100
# Recompute v2 84/100
# Recompute v2 85/100
# Recompute v2 86/100
# Recompute v2 87/100
# Recompute v2 88/100
# Recompute v2 89/100
# Recompute v2 90/100
# Recompute v2 91/100
# Recompute v2 92/100
# Recompute v2 93/100
# Recompute v2 94/100
# Recompute v2 95/100
# Recompute v2 96/100
# Recompute v2 97/100
# Recompute v2 98/100
# Recompute v2 99/100
# [ 7. 70. 89. 43. 65. 94. 71. 88. 13. 24. 69.  8. 68.  3. 55. 75. 29. 93.
#  50. 80. 95. 84. 63. 61.  6. 22. 60. 20. 15. 77. 17. 52. 19. 42. 34. 92.
#  98. 97. 62. 39. 14. 76. 33. 54. 12. 57. 79. 99. 83. 86. 58. 51. 11. 26.
#  32. 67. 49. 66.  9. 40. 18. 96. 38. 25. 72. 59. 35. 53. 21. 37. 74. 82.
#   1. 56. 91. 31. 23. 45. 81. 90. 28. 73. 78. 85.  0. 47. 30.  2. 87. 64.
#  16. 27. 41. 46. 44. 10. 48.  5.  4. 36.]
# recompute v2 condknn time:  1.4557042000014917
# [DataScope] => Ray mode for TMC: True
# condpipe time:  0.04386693100241246
# [DataScope] => Ray mode for TMC: True
# (pid=14956) 1 out of 1 TMC_Shapley iterations.
# (pid=14956) 1 out of 1 TMC_Shapley iterations.
# [DataScope] => Ray mode for TMC: True
# (pid=14956) 1 out of 1 TMC_Shapley iterations.
# (pid=14974) 10 out of 100 evaluation iterations for KNN-Shapley (cond).
# (pid=14961) 20 out of 100 evaluation iterations for KNN-Shapley (cond).
# (pid=14974) 30 out of 100 evaluation iterations for KNN-Shapley (cond).
# (pid=14952) 50 out of 100 evaluation iterations for KNN-Shapley (cond).
# (pid=14955) 40 out of 100 evaluation iterations for KNN-Shapley (cond).
# (pid=14956) 60 out of 100 evaluation iterations for KNN-Shapley (cond).
# (pid=14956) 70 out of 100 evaluation iterations for KNN-Shapley (cond).
# (pid=14961) 10 out of 100 evaluation iterations for KNN-Shapley recompute v1 (cond).
# (pid=14961) 20 out of 100 evaluation iterations for KNN-Shapley recompute v1 (cond).
# (pid=14961) 30 out of 100 evaluation iterations for KNN-Shapley recompute v1 (cond).
# (pid=14965) 80 out of 100 evaluation iterations for KNN-Shapley (cond).
# (pid=14975) 90 out of 100 evaluation iterations for KNN-Shapley (cond).
# (pid=14975) 100 out of 100 evaluation iterations for KNN-Shapley (cond).
# (pid=14952) 40 out of 100 evaluation iterations for KNN-Shapley recompute v1 (cond).
# (pid=14975) 50 out of 100 evaluation iterations for KNN-Shapley recompute v1 (cond).
# (pid=14974) 90 out of 100 evaluation iterations for KNN-Shapley recompute v1 (cond).
# (pid=14974) 40 out of 100 evaluation iterations for KNN-Shapley recompute (cond).
# (pid=14974) 60 out of 100 evaluation iterations for KNN-Shapley recompute (cond).
# (pid=14956) 70 out of 100 evaluation iterations for KNN-Shapley recompute (cond).
# (pid=14956) 100 out of 100 evaluation iterations for KNN-Shapley recompute (cond).
# (pid=14961) 90 out of 100 evaluation iterations for KNN-Shapley recompute (cond).
# (pid=14965) 80 out of 100 evaluation iterations for KNN-Shapley recompute (cond).
# (pid=14975) 30 out of 100 evaluation iterations for KNN-Shapley recompute (cond).
# (pid=14979) 60 out of 100 evaluation iterations for KNN-Shapley recompute v1 (cond).
# (pid=14979) 10 out of 100 evaluation iterations for KNN-Shapley recompute (cond).
# (pid=14977) 100 out of 100 evaluation iterations for KNN-Shapley recompute v1 (cond).
# (pid=14973) 20 out of 100 evaluation iterations for KNN-Shapley recompute (cond).
# (pid=14973) 50 out of 100 evaluation iterations for KNN-Shapley recompute (cond).
# (pid=14972) 70 out of 100 evaluation iterations for KNN-Shapley recompute v1 (cond).
# (pid=14972) 80 out of 100 evaluation iterations for KNN-Shapley recompute v1 (cond).
# (pid=14974) 10 out of 100 evaluation iterations for KNN-Shapley.
# (pid=14955) 10 out of 100 evaluation iterations for TMC-Shapley (cond).
# (pid=14955) 30 out of 100 evaluation iterations for TMC-Shapley (cond).
# (pid=14955) 50 out of 100 evaluation iterations for TMC-Shapley (cond).
# (pid=14965) 40 out of 100 evaluation iterations for TMC-Shapley (cond).
# (pid=14975) 20 out of 100 evaluation iterations for TMC-Shapley (cond).
# (pid=14975) 70 out of 100 evaluation iterations for TMC-Shapley (cond).
# (pid=14979) 80 out of 100 evaluation iterations for TMC-Shapley (cond).
# (pid=14979) 90 out of 100 evaluation iterations for TMC-Shapley (cond).
# (pid=14979) 100 out of 100 evaluation iterations for TMC-Shapley (cond).
# (pid=14977) 60 out of 100 evaluation iterations for TMC-Shapley (cond).
# (pid=14961) 20 out of 100 evaluation iterations for KNN-Shapley.
# (pid=14973) 30 out of 100 evaluation iterations for KNN-Shapley.
# (pid=14952) 70 out of 100 evaluation iterations for KNN-Shapley.
# (pid=14952) 40 out of 100 evaluation iterations for TMC-Shapley.
# (pid=14974) 100 out of 100 evaluation iterations for TMC-Shapley.
# (pid=14956) 60 out of 100 evaluation iterations for KNN-Shapley.
# (pid=14956) 80 out of 100 evaluation iterations for KNN-Shapley.
# (pid=14956) 70 out of 100 evaluation iterations for TMC-Shapley.
# (pid=14961) 40 out of 100 evaluation iterations for KNN-Shapley.
# (pid=14965) 50 out of 100 evaluation iterations for KNN-Shapley.
# (pid=14965) 100 out of 100 evaluation iterations for KNN-Shapley.
# (pid=14965) 20 out of 100 evaluation iterations for TMC-Shapley.
# (pid=14979) 30 out of 100 evaluation iterations for TMC-Shapley.
# (pid=14976) 10 out of 100 evaluation iterations for TMC-Shapley.
# (pid=14976) 60 out of 100 evaluation iterations for TMC-Shapley.
# (pid=14977) 50 out of 100 evaluation iterations for TMC-Shapley.
# (pid=14977) 80 out of 100 evaluation iterations for TMC-Shapley.
# (pid=14973) 90 out of 100 evaluation iterations for KNN-Shapley.
# (pid=14973) 90 out of 100 evaluation iterations for TMC-Shapley.
# (pid=14955) 60 out of 100 evaluation iterations for Random.
# (pid=14965) 20 out of 100 evaluation iterations for Random.
# (pid=14975) 30 out of 100 evaluation iterations for Random.
# (pid=14979) 50 out of 100 evaluation iterations for Random.
# (pid=14979) 100 out of 100 evaluation iterations for Random.
# (pid=14976) 40 out of 100 evaluation iterations for Random.
# (pid=14976) 80 out of 100 evaluation iterations for Random.
# (pid=14977) 70 out of 100 evaluation iterations for Random.
# (pid=14973) 10 out of 100 evaluation iterations for Random.
# (pid=14972) 90 out of 100 evaluation iterations for Random.
# [DataScope] => Running poisoning experiment
# Successfully created the directory .//results/label_i_1100_UCI_pipe_0/i-1-time-24-11-2021-13-36-25/poisoning/
# [Datascope] => use tabular backdoors
# [DataScope] => Start KNN recompute v1
# Recompute v1 0/100
# Recompute v1 1/100
# Recompute v1 2/100
# Recompute v1 3/100
# Recompute v1 4/100
# Recompute v1 5/100
# Recompute v1 6/100
# Recompute v1 7/100
# Recompute v1 8/100
# Recompute v1 9/100
# Recompute v1 10/100
# Recompute v1 11/100
# Recompute v1 12/100
# Recompute v1 13/100
# Recompute v1 14/100
# Recompute v1 15/100
# Recompute v1 16/100
# Recompute v1 17/100
# Recompute v1 18/100
# Recompute v1 19/100
# Recompute v1 20/100
# Recompute v1 21/100
# Recompute v1 22/100
# Recompute v1 23/100
# Recompute v1 24/100
# Recompute v1 25/100
# Recompute v1 26/100
# Recompute v1 27/100
# Recompute v1 28/100
# Recompute v1 29/100
# Recompute v1 30/100
# Recompute v1 31/100
# Recompute v1 32/100
# Recompute v1 33/100
# Recompute v1 34/100
# Recompute v1 35/100
# Recompute v1 36/100
# Recompute v1 37/100
# Recompute v1 38/100
# Recompute v1 39/100
# Recompute v1 40/100
# Recompute v1 41/100
# Recompute v1 42/100
# Recompute v1 43/100
# Recompute v1 44/100
# Recompute v1 45/100
# Recompute v1 46/100
# Recompute v1 47/100
# Recompute v1 48/100
# Recompute v1 49/100
# Recompute v1 50/100
# Recompute v1 51/100
# Recompute v1 52/100
# Recompute v1 53/100
# Recompute v1 54/100
# Recompute v1 55/100
# Recompute v1 56/100
# Recompute v1 57/100
# Recompute v1 58/100
# Recompute v1 59/100
# Recompute v1 60/100
# Recompute v1 61/100
# Recompute v1 62/100
# Recompute v1 63/100
# Recompute v1 64/100
# Recompute v1 65/100
# Recompute v1 66/100
# Recompute v1 67/100
# Recompute v1 68/100
# Recompute v1 69/100
# Recompute v1 70/100
# Recompute v1 71/100
# Recompute v1 72/100
# Recompute v1 73/100
# Recompute v1 74/100
# Recompute v1 75/100
# Recompute v1 76/100
# Recompute v1 77/100
# Recompute v1 78/100
# Recompute v1 79/100
# Recompute v1 80/100
# Recompute v1 81/100
# Recompute v1 82/100
# Recompute v1 83/100
# Recompute v1 84/100
# Recompute v1 85/100
# Recompute v1 86/100
# Recompute v1 87/100
# Recompute v1 88/100
# Recompute v1 89/100
# Recompute v1 90/100
# Recompute v1 91/100
# Recompute v1 92/100
# Recompute v1 93/100
# Recompute v1 94/100
# Recompute v1 95/100
# Recompute v1 96/100
# Recompute v1 97/100
# Recompute v1 98/100
# Recompute v1 99/100
# [11. 74. 78. 90. 52. 84. 55. 92.  8. 33.  1. 79.  6. 61. 34.  3.  5. 31.
#  38. 95. 22. 57. 45. 39. 14. 68. 23. 66. 43. 42. 93. 13. 58. 50. 94. 30.
#  76. 32. 44. 91. 83. 96. 27. 12. 37. 35.  7. 54. 53.  2. 62. 69. 19. 15.
#  29. 85.  0. 48. 24. 98. 18. 46. 97. 77. 21. 25. 99. 41.  4. 26. 81. 75.
#  88. 36. 70. 16. 10. 59. 51. 67. 47. 63. 72. 28. 87. 60. 56. 64. 80. 82.
#  49.  9. 73. 20. 71. 65. 40. 17. 86. 89.]
# [DataScope] => Start KNN recompute v2
# Recompute v2 0/100
# Recompute v2 1/100
# Recompute v2 2/100
# Recompute v2 3/100
# Recompute v2 4/100
# Recompute v2 5/100
# Recompute v2 6/100
# Recompute v2 7/100
# Recompute v2 8/100
# Recompute v2 9/100
# Recompute v2 10/100
# Recompute v2 11/100
# Recompute v2 12/100
# Recompute v2 13/100
# Recompute v2 14/100
# Recompute v2 15/100
# Recompute v2 16/100
# Recompute v2 17/100
# Recompute v2 18/100
# Recompute v2 19/100
# Recompute v2 20/100
# Recompute v2 21/100
# Recompute v2 22/100
# Recompute v2 23/100
# Recompute v2 24/100
# Recompute v2 25/100
# Recompute v2 26/100
# Recompute v2 27/100
# Recompute v2 28/100
# Recompute v2 29/100
# Recompute v2 30/100
# Recompute v2 31/100
# Recompute v2 32/100
# Recompute v2 33/100
# Recompute v2 34/100
# Recompute v2 35/100
# Recompute v2 36/100
# Recompute v2 37/100
# Recompute v2 38/100
# Recompute v2 39/100
# Recompute v2 40/100
# Recompute v2 41/100
# Recompute v2 42/100
# Recompute v2 43/100
# Recompute v2 44/100
# Recompute v2 45/100
# Recompute v2 46/100
# Recompute v2 47/100
# Recompute v2 48/100
# Recompute v2 49/100
# Recompute v2 50/100
# Recompute v2 51/100
# Recompute v2 52/100
# Recompute v2 53/100
# Recompute v2 54/100
# Recompute v2 55/100
# Recompute v2 56/100
# Recompute v2 57/100
# Recompute v2 58/100
# Recompute v2 59/100
# Recompute v2 60/100
# Recompute v2 61/100
# Recompute v2 62/100
# Recompute v2 63/100
# Recompute v2 64/100
# Recompute v2 65/100
# Recompute v2 66/100
# Recompute v2 67/100
# Recompute v2 68/100
# Recompute v2 69/100
# Recompute v2 70/100
# Recompute v2 71/100
# Recompute v2 72/100
# Recompute v2 73/100
# Recompute v2 74/100
# Recompute v2 75/100
# Recompute v2 76/100
# Recompute v2 77/100
# Recompute v2 78/100
# Recompute v2 79/100
# Recompute v2 80/100
# Recompute v2 81/100
# Recompute v2 82/100
# Recompute v2 83/100
# Recompute v2 84/100
# Recompute v2 85/100
# Recompute v2 86/100
# Recompute v2 87/100
# Recompute v2 88/100
# Recompute v2 89/100
# Recompute v2 90/100
# Recompute v2 91/100
# Recompute v2 92/100
# Recompute v2 93/100
# Recompute v2 94/100
# Recompute v2 95/100
# Recompute v2 96/100
# Recompute v2 97/100
# Recompute v2 98/100
# Recompute v2 99/100
# [ 8. 60. 84. 91. 20. 79. 56. 57. 16. 36.  1. 69.  5. 94. 37.  3.  4. 35.
#  41. 98. 23. 76. 50. 40. 12. 64. 26. 61. 45. 42. 92. 22. 77. 54. 87. 31.
#  62. 34. 43. 63. 59. 89. 55.  9. 38. 32.  7. 19. 18.  2. 86. 83. 24. 13.
#  30. 96.  0. 51. 28. 97. 27. 47. 78. 74. 25. 44. 75. 48.  6. 53. 95. 72.
#  93. 33. 66. 14. 11. 68. 46. 82. 49. 88. 67. 29. 58. 73. 17. 81. 71. 70.
#  52. 10. 65. 15. 90. 85. 39. 21. 80. 99.]
# [DataScope] => Ray mode for TMC: True
# (pid=14973) 1 out of 1 TMC_Shapley iterations.
# [DataScope] => Ray mode for TMC: True
# (pid=14973) 1 out of 1 TMC_Shapley iterations.
# [DataScope] => Ray mode for TMC: True
# (pid=14973) 1 out of 1 TMC_Shapley iterations.
# (pid=14952) 10 out of 100 evaluation iterations for KNN-Shapley (cond).
# (pid=14955) 20 out of 100 evaluation iterations for KNN-Shapley (cond).
# (pid=14972) 30 out of 100 evaluation iterations for KNN-Shapley (cond).
# (pid=14977) 40 out of 100 evaluation iterations for KNN-Shapley (cond).
# (pid=14952) 90 out of 100 evaluation iterations for KNN-Shapley (cond).
# (pid=14955) 20 out of 100 evaluation iterations for KNN-Shapley recompute v1 (cond).
# (pid=14961) 60 out of 100 evaluation iterations for KNN-Shapley recompute v1 (cond).
# (pid=14965) 100 out of 100 evaluation iterations for KNN-Shapley (cond).
# (pid=14965) 40 out of 100 evaluation iterations for KNN-Shapley recompute v1 (cond).
# (pid=14979) 60 out of 100 evaluation iterations for KNN-Shapley (cond).
# (pid=14976) 70 out of 100 evaluation iterations for KNN-Shapley (cond).
# (pid=14976) 80 out of 100 evaluation iterations for KNN-Shapley (cond).
# (pid=14977) 10 out of 100 evaluation iterations for KNN-Shapley recompute v1 (cond).
# (pid=14977) 30 out of 100 evaluation iterations for KNN-Shapley recompute v1 (cond).
# (pid=14977) 70 out of 100 evaluation iterations for KNN-Shapley recompute v1 (cond).
# (pid=14973) 50 out of 100 evaluation iterations for KNN-Shapley (cond).
# (pid=14973) 50 out of 100 evaluation iterations for KNN-Shapley recompute v1 (cond).
# (pid=14972) 80 out of 100 evaluation iterations for KNN-Shapley recompute v1 (cond).
# (pid=14956) 90 out of 100 evaluation iterations for KNN-Shapley recompute v1 (cond).
# (pid=14952) 100 out of 100 evaluation iterations for KNN-Shapley recompute v1 (cond).
# (pid=14952) 60 out of 100 evaluation iterations for KNN-Shapley recompute (cond).
# (pid=14952) 20 out of 100 evaluation iterations for TMC-Shapley (cond).
# (pid=14974) 50 out of 100 evaluation iterations for KNN-Shapley recompute (cond).
# (pid=14961) 10 out of 100 evaluation iterations for KNN-Shapley recompute (cond).
# (pid=14961) 80 out of 100 evaluation iterations for KNN-Shapley recompute (cond).
# (pid=14965) 10 out of 100 evaluation iterations for TMC-Shapley (cond).
# (pid=14975) 20 out of 100 evaluation iterations for KNN-Shapley recompute (cond).
# (pid=14975) 40 out of 100 evaluation iterations for KNN-Shapley recompute (cond).
# (pid=14975) 70 out of 100 evaluation iterations for KNN-Shapley recompute (cond).
# (pid=14975) 90 out of 100 evaluation iterations for KNN-Shapley recompute (cond).
# (pid=14976) 30 out of 100 evaluation iterations for TMC-Shapley (cond).
# (pid=14973) 30 out of 100 evaluation iterations for KNN-Shapley recompute (cond).
# (pid=14973) 100 out of 100 evaluation iterations for KNN-Shapley recompute (cond).
# (pid=14977) 40 out of 100 evaluation iterations for TMC-Shapley (cond).
# (pid=14977) 50 out of 100 evaluation iterations for TMC-Shapley (cond).
# (pid=14952) 70 out of 100 evaluation iterations for TMC-Shapley (cond).
# (pid=14955) 60 out of 100 evaluation iterations for KNN-Shapley.
# (pid=14955) 100 out of 100 evaluation iterations for KNN-Shapley.
# (pid=14956) 50 out of 100 evaluation iterations for KNN-Shapley.
# (pid=14956) 70 out of 100 evaluation iterations for KNN-Shapley.
# (pid=14961) 10 out of 100 evaluation iterations for KNN-Shapley.
# (pid=14961) 30 out of 100 evaluation iterations for KNN-Shapley.
# (pid=14965) 80 out of 100 evaluation iterations for TMC-Shapley (cond).
# (pid=14975) 80 out of 100 evaluation iterations for KNN-Shapley.
# (pid=14979) 90 out of 100 evaluation iterations for KNN-Shapley.
# (pid=14976) 20 out of 100 evaluation iterations for KNN-Shapley.
# (pid=14973) 90 out of 100 evaluation iterations for TMC-Shapley (cond).
# (pid=14973) 40 out of 100 evaluation iterations for KNN-Shapley.
# (pid=14972) 60 out of 100 evaluation iterations for TMC-Shapley (cond).
# (pid=14972) 100 out of 100 evaluation iterations for TMC-Shapley (cond).
# (pid=14952) 20 out of 100 evaluation iterations for TMC-Shapley.
# (pid=14952) 80 out of 100 evaluation iterations for TMC-Shapley.
# (pid=14974) 100 out of 100 evaluation iterations for TMC-Shapley.
# (pid=14955) 40 out of 100 evaluation iterations for TMC-Shapley.
# (pid=14961) 30 out of 100 evaluation iterations for Random.
# (pid=14979) 10 out of 100 evaluation iterations for TMC-Shapley.
# (pid=14979) 60 out of 100 evaluation iterations for TMC-Shapley.
# (pid=14979) 90 out of 100 evaluation iterations for TMC-Shapley.
# (pid=14979) 10 out of 100 evaluation iterations for Random.
# (pid=14976) 70 out of 100 evaluation iterations for TMC-Shapley.
# (pid=14976) 20 out of 100 evaluation iterations for Random.
# (pid=14973) 50 out of 100 evaluation iterations for TMC-Shapley.
# (pid=14972) 30 out of 100 evaluation iterations for TMC-Shapley.
# (pid=14977) 40 out of 100 evaluation iterations for Random.
# (pid=14955) 70 out of 100 evaluation iterations for Random.
# (pid=14955) 90 out of 100 evaluation iterations for Random.
# (pid=14955) 100 out of 100 evaluation iterations for Random.
# (pid=14956) 50 out of 100 evaluation iterations for Random.
# (pid=14961) 80 out of 100 evaluation iterations for Random.
# (pid=14979) 60 out of 100 evaluation iterations for Random.
# [DataScope] => All experiments done!

# %%
test_dict = {0: np.array([0]), 1: np.array([1]), 2: np.array([2])}
# Out:
# {0: array([0]), 2: array([2])}
